# %% [markdown]
# #### 2019/04/27
# ## ideas
#
# - [ ] 球坐标经纬度范围加zoom信息及其归一化与置信度，经纬度上的高斯，随时间方差增大
# - [ ] region proposal with hsv 记录邻域, 宽阈值筛选， 然后再精细化阈值， 辨认脸型
#
# ## 今日任务
# - [ ] 完成了参数归一化, 目前实验看来不太可行, 因为拓展到全局之后效果很差,大概30多, 之前前3层的应该是拜托后面基层的挽救了

# %% [markdown]
# ## 以前任务
# - [ ] 把annotation里面的游程编码一条一条在原图上标出来,搞懂,并且会用coco.py给的接口
# - [ ] 搞明白评价接口,能随意使用判定预测结果的准确率
# - [x] 开始找DQN pytorch的代码
# - [ ] 开始找PPO pytorch的代码
# - [ ] 找到rcnn训练崩溃的原因
# - [ ] 训练一个神经网络来指导(为instance打分)选择对象以及调整, 考虑bbox大小, 中心位置占画面长宽的比例,
# - [ ] 确定一个默认的overview视角作为后备
# - [ ] 设计一个机制,五级打分:没啥变化, 变好了, 变坏了, 太好了, 太坏了, 人只进行这样的评判, 然后可以在线地传递到instance的打分上
# - [ ] 结合yolov3与pose body, 实现快速识别
# - [ ] 自动提取object的skeleton信息，然后dqn之，以完善边缘的准确率
# - [x] 开始探索zoo
# - [ ] 赋予AI一些记忆(Memory),哪怕7秒的记忆,让前面一段时间识别的东西有留存,并且指导最新的工作.而不是摄像头的机械记忆.

# %% [markdown]
# - [x] 参数归一化，梯度下降也要归一化，normalization的在线版，一次直接分配到位，使得梯度更新之后所有weight的和依然为1, 观察考虑HSV,保存历史数据
#     + 直观的目的是为了防止输出特别大
#     - 也许它具有稳定后层输入的分布的功能呢
# - [x] 理解清楚optimizer在BP中的具体做法
# - [x] 理解清楚module的包含内容
# - [x] 理解清楚parameters
# - [x] xtool, 图片显示工具 eg loss的记录与准实时画图，以及GIF图生成
# - [x] xtool, json数据的动态存储
# - [x] xtool, 生成训练report工具, 保存历史数据, weight显示工具
# - [x] 解决zoom与speed的关系问题
# - [x] 结合yolov3与face detection, 实现快速识别
# - [x] 写2000字的EE8001
# - [x] 小改xtool，实现不显示只保存图片

# %% [markdown]
# ## 工作

# %% [markdown]
# ### quadro

# %% [markdown]
# ```log
# 2019-04-27 19:37:53.707 1152-1374/? D/HWMultiGW: setGateWay 192.168.99.1
# 2019-04-27 19:38:24.767 1152-1374/? D/HWMultiGW: setGateWay 192.168.99.1
# 2019-04-27 19:38:55.857 1152-1374/? D/HWMultiGW: setGateWay 192.168.99.1
# 2019-04-27 19:39:15.192 1984-9502/? I/ThermalService: Receive temperature change, type: 9, temp: 29 from thermald
# 2019-04-27 19:39:15.192 1984-9502/? I/ThermalTrace_ThermalRaise: Battery:29,28,29
# 2019-04-27 19:39:26.930 1152-1374/? D/HWMultiGW: setGateWay 192.168.99.1
# 2019-04-27 19:39:27.339 22988-22988/? D/test: ip = 192.168.99.201
# 2019-04-27 19:39:28.152 22988-22988/? D/rt_log: [Java_com_rtspclient_UAVNative_RVSTConnect   150] ip=192.168.99.1   port=9001  type=2
# 2019-04-27 19:39:28.191 22988-25615/? D/rt_log: [Java_com_rtspclient_RTDeviceCmd_connectSocket   103] ip=192.168.234.1 was drop using defaule xxx,xxx.99.1
# 2019-04-27 19:39:28.342 22988-22988/? D/rt_log: [addIpcam   515] rt_stream_in_init success pFilePath = rtsp://192.168.99.1/11 socketType = 1
# 2019-04-27 19:39:44.192 1453-1529/? D/bt_dump_addr: btif_av_state_started_handler: bd_addr c4-6e-7b-d6-xx-xx
# ```

# %% [markdown]
# ### tplink

# %% [markdown]
# ```syslog
# 2019-04-27 19:52:06.355 26541-26763/? E/NAT_P2P: [2019-04-27 19:52:06] _p2p_local_event_cb:1171 [stun_ctx: 0xd0dcaf80]failed, events 0x11
# 2019-04-27 19:52:19.658 26541-26763/? E/NAT_P2P: [2019-04-27 19:52:19] _p2p_listener_cb:345 1(ctx: 0xd0dcaf80). accept fd 103
# 2019-04-27 19:52:46.608 26541-26763/? E/NAT_P2P: [2019-04-27 19:52:46] _p2p_local_event_cb:1171 [stun_ctx: 0xd0dcaf80]failed, events 0x11
# 2019-04-27 19:52:46.612 26541-26763/? E/NAT_P2P: [2019-04-27 19:52:46] _p2p_ctl_read_cb:245 1. obj->opid 2, ctl.opid 2
# 2019-04-27 19:52:46.612 26541-26763/? E/NAT_P2P: [2019-04-27 19:52:46] _p2p_ctl_read_cb:250 1. got ctl message 0, break event
# 2019-04-27 19:52:46.612 26541-26763/? E/NAT_P2P: [2019-04-27 19:52:46] _p2p_event_thread:374 1. event thread exit
# 2019-04-27 19:52:48.310 26541-26763/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_obj_clear:189 1. cleared
# 2019-04-27 19:52:48.354 26541-26597/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_obj_clear:189 1. cleared
# 2019-04-27 19:52:48.369 26541-27328/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_dns_request:592 [stun_ctx: 0xb356da80]dns request 'n-service-ipc.tplinkcloud.com.cn:443'...
# 2019-04-27 19:52:48.370 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_event_thread:372 0. event thread started
# 2019-04-27 19:52:48.371 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_listener_cb:341 0. init local control listener(127.0.0.1:47373) OK
# 2019-04-27 19:52:48.420 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_dns_cb:513 [stun_ctx: 0xb356da80]dns query for control server OK '212.64.117.48:443'
# 2019-04-27 19:52:48.420 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_dns_cb:534 [stun_ctx: 0xb356da80]tcp connecting to control 'n-service-ipc.tplinkcloud.com.cn' ...
# 2019-04-27 19:52:48.491 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_control_event_cb:1038 Use cached server url
# 2019-04-27 19:52:48.491 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_on_query_host_success:821 [stun_ctx: 0xb356da80]got service host '111.231.58.151'
# 2019-04-27 19:52:48.491 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_dns_request:592 [stun_ctx: 0xb356da80]dns request '111.231.58.151:3478'...
# 2019-04-27 19:52:48.543 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_dns_cb:513 [stun_ctx: 0xb356da80]dns query for stun server OK '111.231.58.151:3478'
# 2019-04-27 19:52:48.543 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_stun_request:379 [stun_ctx: 0xb356da80]stun query set timeout:100
# 2019-04-27 19:52:48.544 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_stun_request:404 [stun_ctx: 0xb356da80]building stun request(1)
# 2019-04-27 19:52:48.544 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_stun_request:412 [stun_ctx: 0xb356da80]building stun request(2)
# 2019-04-27 19:52:48.544 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_stun_request:435 [stun_ctx: 0xb356da80]bind local addr ipv4: 10.74.68.42
# 2019-04-27 19:52:48.545 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_stun_request:444 [stun_ctx: 0xb356da80]fd 104, query stun address...
# 2019-04-27 19:52:48.545 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_stun_query:227 [stun_ctx: 0xb356da80]query stun server for external address.... time:1556365968545
# 2019-04-27 19:52:48.597 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_stun_event_cb:325 [stun_ctx: 0xb356da80]fd 104, got my stun address: '182.239.119.123
#     11908
#     10.74.68.42
#     38022
#     6
#     '
# 2019-04-27 19:52:48.598 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_dns_request:592 [stun_ctx: 0xb356da80]dns request 'n-wap-ipc.tplinkcloud.com.cn:443'...
# 2019-04-27 19:52:48.650 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_dns_cb:513 [stun_ctx: 0xb356da80]dns query for control server OK '54.223.121.32:443'
# 2019-04-27 19:52:48.650 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_dns_cb:530 [stun_ctx: 0xb356da80]tcp connecting to control 'n-wap-ipc.tplinkcloud.com.cn' ...
# 2019-04-27 19:52:48.707 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_control_event_cb:1054 [stun_ctx: 0xb356da80]tcp connected with 'n-wap-ipc.tplinkcloud.com.cn'
# 2019-04-27 19:52:48.708 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] connect_to_control_ssl:1232 _p2p_control_event_cb 0
# 2019-04-27 19:52:48.708 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] connect_to_control_ssl:1262 _p2p_control_event_cb 3
# 2019-04-27 19:52:48.708 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_control_event_cb:1112 [stun_ctx: 0xb356da80]connection success, event:0x80
# 2019-04-27 19:52:48.727 26541-27335/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_dns_request:491 [relay_ctx: 0xb42cee00]dns request 'n-wap-ipc.tplinkcloud.com.cn:443' ...
# 2019-04-27 19:52:48.728 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_event_thread:372 1. event thread started
# 2019-04-27 19:52:48.729 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_listener_cb:341 1. init local control listener(127.0.0.1:54332) OK
# 2019-04-27 19:52:48.778 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_dns_cb:441 [relay_ctx: 0xb42cee00]dns query for control server OK '54.223.121.32:443'
# 2019-04-27 19:52:48.779 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_dns_cb:450 [relay_ctx: 0xb42cee00]tcp connecting to control 'n-service-ipc.tplinkcloud.com.cn' ...
# 2019-04-27 19:52:48.833 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_control_event_cb:2316 [relay_ctx: 0xb42cee00]tcp connected with 'n-service-ipc.tplinkcloud.com.cn'
# 2019-04-27 19:52:48.982 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_control_event_cb:2331 [relay_ctx: 0xb42cee00]ssl connected with 'n-service-ipc.tplinkcloud.com.cn'
# 2019-04-27 19:52:48.982 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_control_event_cb:2332 [relay_ctx: 0xb42cee00]query relay service host...
# 2019-04-27 19:52:48.982 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:48] _p2p_control_event_cb:2340 [relay_ctx: 0xb42cee00]query relay service.../relayservice?deviceid=0018B6B7F6E5843DA35FEA6861446C6F1B72C8C8&type=video&resolution=VGA
# 2019-04-27 19:52:49.125 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_control_event_cb:1076 [stun_ctx: 0xb356da80]ssl connected with 'n-service-ipc.tplinkcloud.com.cn'
# 2019-04-27 19:52:49.125 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_control_event_cb:1077 [stun_ctx: 0xb356da80]query stun service host...
# 2019-04-27 19:52:49.125 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_control_event_cb:1081 [stun_ctx: 0xb356da80]request p2p query p2p session...
# 2019-04-27 19:52:49.126 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_control_event_cb:1112 [stun_ctx: 0xb356da80]connection success, event:0x80
# 2019-04-27 19:52:49.282 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_control_read_cb:2190 [relay_ctx: 0xb42cee00]got relay service response ''
# 2019-04-27 19:52:49.283 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_dns_request:491 [relay_ctx: 0xb42cee00]dns request 'n-relay-ipc.tplinkcloud.com.cn:443' ...
# 2019-04-27 19:52:49.334 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_dns_cb:441 [relay_ctx: 0xb42cee00]dns query for relay server OK '115.159.17.48:443'
# 2019-04-27 19:52:49.335 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_dns_cb:464 [relay_ctx: 0xb42cee00]tcp connecting to relay 'n-relay-ipc.tplinkcloud.com.cn:443' ...
# 2019-04-27 19:52:49.384 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_control_read_cb:948 [stun_ctx: 0xb356da80]got p2p peer address '
#     113.140.62.174
#     32845
#     192.168.1.108
#     47244
#     2', begin UDP hole punching...
# 2019-04-27 19:52:49.384 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_relay_event_cb:1256 [relay_ctx: 0xb42cee00]tcp connected with relay server==== 'n-service-ipc.tplinkcloud.com.cn'
# 2019-04-27 19:52:49.384 26541-27330/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_init_punch_ctx:721 [stun_ctx: 0xb356da80]113.140.62.174:32845-192.168.1.108:47244, 2
# 2019-04-27 19:52:49.528 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_relay_event_cb:1289 [relay_ctx: 0xb42cee00]tcp connected with 'n-relay-ipc.tplinkcloud.com.cn:443' (for POST multipart)
# 2019-04-27 19:52:49.529 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_relay_event_cb:1302 [relay_ctx: 0xb42cee00]query stream...'POST /relayservice?deviceid=0018B6B7F6E5843DA35FEA6861446C6F1B72C8C8&type=video&resolution=VGA HTTP/1.1
#     User-Agent: Client=SurveillanceSystem_Android 2.8.14/1.3
#     Keep-Relay: 3600
#     Accept: */*
#     Host: n-relay-ipc.tplinkcloud.com.cn:443
#     Content-Type: multipart/mixed;boundary=--client-stream-boundary--
#     Content-Length: 9223372036854775807
#     X-token: 0021cb4a-f1658eeb23ea4cf0b623776
#     X-Client-Model: KNT-AL20
#     X-Client-UUID: 00000000-22f3-24f4-ffff-ffffdf80535a
#     X-Client-SessionID: aQc0GpfDnhcXtAsnB37o6YwLnhSApHdP
#     Cookie: AWSELB=1836ac201fa055f0ce2693deceb7f3d8
#
#     '
# 2019-04-27 19:52:49.629 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_relay_read_cb:1160 got relay response:
#     HTTP/1.1 200 OK
#     Date: Sat, 27 Apr 2019 11:52:50 GMT
#     Content-Type: multipart/mixed; boundary=--device-stream-boundary--
#     Content-Length: 9223372036854775807
#     Connection: keep-alive
#     pragma: no-cache
#     cache-control: no-cache
#     server: relayd
#     X-Client-Id: Y2YwMDJiYjctMjViOC00MWIwLTk1OWEtMTQ5ZWUwMjc1NTUx
#     X-Request-Type: relayservice-appStream
# 2019-04-27 19:52:49.630 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_relay_handle_stream_response:888 [relay_ctx: 0xb42cee00]Ahaaa, got relay stream :)
# 2019-04-27 19:52:49.630 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_relay_handle_stream_response:897 [relay_ctx: 0xb42cee00]got X-Client-Id: [Y2YwMDJiYjctMjViOC00MWIwLTk1OWEtMTQ5ZWUwMjc1NTUx]
# 2019-04-27 19:52:49.640 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_listener_cb:345 1(ctx: 0xb42cee00). accept fd 123
# 2019-04-27 19:52:49.679 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_relaycontrol_event_cb:1650 [relay_ctx: 0xb42cee00]tcp connected with 'n-relay-ipc.tplinkcloud.com.cn:443' (for relaycontrol)
# 2019-04-27 19:52:49.679 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_relaycontrol_event_cb:1660 [relay_ctx: 0xb42cee00]tcp connected with relay control server==== 'n-service-ipc.tplinkcloud.com.cn'
# 2019-04-27 19:52:49.813 26541-27337/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_relaycontrol_event_cb:1650 [relay_ctx: 0xb42cee00]tcp connected with 'n-relay-ipc.tplinkcloud.com.cn:443' (for relaycontrol)
# 2019-04-27 19:52:49.986 26541-26630/? E/NAT_P2P: [2019-04-27 19:52:49] _p2p_get_nat_type_cb:463 [stun_ctx: 0xb356da80]NAT type: 6(0x6)
# 2019-04-27 19:53:14.813 26541-27337/? E/NAT_P2P: [2019-04-27 19:53:14] _p2p_relaycontrol_do_heartbeat:1453 [relay_ctx: 0xb42cee00]do heartbeat
# 2019-04-27 19:53:15.185 26541-27337/? E/NAT_P2P: [2019-04-27 19:53:15] _p2p_relaycontrol_read_cb:1623 [relay_ctx: 0xb42cee00]response from relaycontrol: [HTTP/1.1 200 OK
#     Date: Sat, 27 Apr 2019 11:53:16 GMT
#     Content-Length: 0
#     Connection: keep-alive
#     pragma: no-cache
#     cache-control: no-cache
#     server: relayd
#     X-Request-Type: relaycontrol-heartbeat
#
#     ]
# 2019-04-27 19:53:40.186 26541-27337/? E/NAT_P2P: [2019-04-27 19:53:40] _p2p_relaycontrol_do_heartbeat:1453 [relay_ctx: 0xb42cee00]do heartbeat
# 2019-04-27 19:53:40.865 26541-27337/? E/NAT_P2P: [2019-04-27 19:53:40] _p2p_relaycontrol_read_cb:1623 [relay_ctx: 0xb42cee00]response from relaycontrol: [HTTP/1.1 200 OK
#     Date: Sat, 27 Apr 2019 11:53:41 GMT
#     Content-Length: 0
#     Connection: keep-alive
#     pragma: no-cache
#     cache-control: no-cache
#     server: relayd
#     X-Request-Type: relaycontrol-heartbeat
#
#     ]
# 2019-04-27 19:54:05.867 26541-27337/? E/NAT_P2P: [2019-04-27 19:54:05] _p2p_relaycontrol_do_heartbeat:1453 [relay_ctx: 0xb42cee00]do heartbeat
# 2019-04-27 19:54:06.480 26541-27337/? E/NAT_P2P: [2019-04-27 19:54:06] _p2p_relaycontrol_read_cb:1623 [relay_ctx: 0xb42cee00]response from relaycontrol: [HTTP/1.1 200 OK
#     Date: Sat, 27 Apr 2019 11:54:07 GMT
#     Content-Length: 0
#     Connection: keep-alive
#     pragma: no-cache
#     cache-control: no-cache
#     server: relayd
#     X-Request-Type: relaycontrol-heartbeat
#
#     ]
# 2019-04-27 19:54:31.481 26541-27337/? E/NAT_P2P: [2019-04-27 19:54:31] _p2p_relaycontrol_do_heartbeat:1453 [relay_ctx: 0xb42cee00]do heartbeat
# 2019-04-27 19:54:31.550 26541-27337/? E/NAT_P2P: [2019-04-27 19:54:31] _p2p_relaycontrol_read_cb:1623 [relay_ctx: 0xb42cee00]response from relaycontrol: [HTTP/1.1 200 OK
#     Date: Sat, 27 Apr 2019 11:54:32 GMT
#     Content-Length: 0
#     Connection: keep-alive
#     pragma: no-cache
#     cache-control: no-cache
#     server: relayd
#     X-Request-Type: relaycontrol-heartbeat
#
#     ]
# 2019-04-27 19:54:56.551 26541-27337/? E/NAT_P2P: [2019-04-27 19:54:56] _p2p_relaycontrol_do_heartbeat:1453 [relay_ctx: 0xb42cee00]do heartbeat
# 2019-04-27 19:54:56.620 26541-27337/? E/NAT_P2P: [2019-04-27 19:54:56] _p2p_relaycontrol_read_cb:1623 [relay_ctx: 0xb42cee00]response from relaycontrol: [HTTP/1.1 200 OK
#     Date: Sat, 27 Apr 2019 11:54:57 GMT
#     Content-Length: 0
#     Connection: keep-alive
#     pragma: no-cache
#     cache-control: no-cache
#     server: relayd
#     X-Request-Type: relaycontrol-heartbeat
#
#     ]
# 2019-04-27 19:55:21.620 26541-27337/? E/NAT_P2P: [2019-04-27 19:55:21] _p2p_relaycontrol_do_heartbeat:1453 [relay_ctx: 0xb42cee00]do heartbeat
# 2019-04-27 19:55:21.680 26541-27337/? E/NAT_P2P: [2019-04-27 19:55:21] _p2p_relaycontrol_read_cb:1623 [relay_ctx: 0xb42cee00]response from relaycontrol: [HTTP/1.1 200 OK
#     Date: Sat, 27 Apr 2019 11:55:22 GMT
#     Content-Length: 0
#     Connection: keep-alive
#     pragma: no-cache
#     cache-control: no-cache
#     server: relayd
#     X-Request-Type: relaycontrol-heartbeat
#
#     ]
# 2019-04-27 19:55:39.640 26541-27337/? E/NAT_P2P: [2019-04-27 19:55:39] _p2p_relay_event_cb:1347 [relay_ctx: 0xb42cee00]connection error, bev: 0xba03d180(local), event:0x11, status: 9, p2pflags: 0x91
# 2019-04-27 19:55:39.640 26541-27337/? E/NAT_P2P: [2019-04-27 19:55:39] _p2p_event_thread:374 1. event thread exit
# 2019-04-27 19:55:39.640 26541-27337/? E/NAT_P2P: [2019-04-27 19:55:39] _p2p_relaycontrol_do_disconnect:1603 [relay_ctx: 0xb42cee00]do disconnect
# 2019-04-27 19:55:39.641 26541-27337/? E/NAT_P2P: [2019-04-27 19:55:39] _p2p_relaycontrol_do_request:1427 _p2p_relaycontrol_do_request Immediately 466/466
# 2019-04-27 19:55:39.643 26541-27337/? E/NAT_P2P: [2019-04-27 19:55:39] _p2p_obj_clear:189 1. cleared
# 2019-04-27 19:55:39.645 26541-26597/? E/NAT_P2P: [2019-04-27 19:55:39] _p2p_obj_clear:189 1. cleared
# 2019-04-27 19:55:48.636 26541-27330/? E/NAT_P2P: [2019-04-27 19:55:48] _p2p_listener_cb:345 0(ctx: 0xb356da80). accept fd 94
# 2019-04-27 20:02:00.276 26541-27330/? E/NAT_P2P: [2019-04-27 20:02:00] _p2p_local_event_cb:1171 [stun_ctx: 0xb356da80]failed, events 0x11
# ```

# %% [markdown]
# # training PA2
# ## requirements
# ### Part1 (a)
# - [x] MLP,
# - [x] linear activation & MSE as the loss function
# - [x] new activation and/or loss function time-component
# ### Part1 (b)
# - None
# ### Part1 (c)
# - compare (a)中的两个效果

# %% [markdown]
# ### Part2 (a)
# regularization
# - [ ] L2
# - [ ] L1
# - [ ] drop-out
# - [ ] ensembling
# - [ ] early-stopping
# - [ ] data augmentation
# - [ ] etc.
# ### Part1 (b)
# add various types of architecture components
# - [ ] batch norm
# - [ ] ResNet
# - [ ] DenseNet
# - [ ] attention
# - [ ] etc
